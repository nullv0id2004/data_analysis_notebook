# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:\\230968160-MANAS GOEL\\WEEK 3\\mtcars.csv')
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
bestmpg = df[df.mpg == df.mpg.max()]
bestmpg.model
# Out:
# 19    Toyota Corolla
# Name: model, dtype: object

# %%
worstmpg = df[df.mpg == df.mpg.min()]
worstmpg.model
# Out:
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# Name: model, dtype: object

# %%
besthorsepower = df[df.hp == df.hp.max()]
besthorsepower
# Out:
#             model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8

# %%
df.disp.describe()
# Out:
# count     32.000000
# mean     230.721875
# std      123.938694
# min       71.100000
# 25%      120.825000
# 50%      196.300000
# 75%      326.000000
# max      472.000000
# Name: disp, dtype: float64

# %%
medianhp = df[df.hp == df.hp.median()]
medianhp
# Out:
#         model   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 9    Merc 280  19.2    6  167.6  123  3.92  3.44  18.3   1   0     4     4
# 10  Merc 280C  17.8    6  167.6  123  3.92  3.44  18.9   1   0     4     4

# %%
manual = df.loc[(df['am']==0)]
manual.mpg.mean()
# Out:
# 17.147368421052633

# %%
auto = df.loc[(df['am']==1)]
auto.mpg.mean()
# Out:
# 24.39230769230769

# %%
import matplotlib.pyplot as plt
plt.hist(df.mpg,color='skyblue', edgecolor='black')
plt.xlabel('mpg')
plt.ylabel('Frequency')
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
cyltype = df.cyl.unique()
df.boxplot(by ='cyl', column =['mpg'], grid = False) 
plt.title('boxplot of miler per gallon based cylinder type')
# Out:
# Text(0.5, 1.0, 'boxplot of miler per gallon based cylinder type')

# %%
pd.crosstab(manual.count(),auto.count())
# Out:
# col_0  13
# row_0
# 19     12

# %%
pd.crosstab(df.am,df.cyl)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
correlation = df['wt'].corr(df['mpg'])
correlation
# Out:
# -0.8676593765172281

# %% [markdown]
# # Excercise 2

# %%
df1 = pd.read_csv('D:\\230968160-MANAS GOEL\\WEEK 3\\bollywood.csv')
df1
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df1.shape[0]
# Out:
# 149

# %%
Genre = df1.Genre.unique()
df1['Genre'].value_counts()
# Out:
# Comedy       36
#  Drama       35
# Thriller     26
# Romance      25
# Action       21
# Thriller      3
# Action        3
# Name: Genre, dtype: int64

# %%
df1['Genre'].value_counts().index.tolist()[:1]
# Out:
# ['Comedy']

# %%
df1.Genre.mode()
# Out:
# 0    Comedy
# Name: Genre, dtype: object

# %%
df1.ReleaseTime.unique()
df1.groupby(['Genre','ReleaseTime']).size().reset_index(name='count')
# Out:
#         Genre ReleaseTime  count
# 0      Drama           FS      4
# 1      Drama           HS      6
# 2      Drama           LW      1
# 3      Drama            N     24
# 4      Action          FS      3
# 5      Action          HS      3
# 6      Action          LW      3
# 7      Action           N     12
# 8     Action            N      3
# 9      Comedy          FS      3
# 10     Comedy          HS      5
# 11     Comedy          LW      5
# 12     Comedy           N     23
# 13    Romance          FS      3
# 14    Romance          HS      3
# 15    Romance          LW      4
# 16    Romance           N     15
# 17   Thriller          FS      4
# 18   Thriller          HS      1
# 19   Thriller          LW      1
# 20   Thriller           N     20
# 21  Thriller           LW      1
# 22  Thriller            N      2

# %%
df1.drop('month',axis ='columns')
# df1['month'] = df1['Release Date'].str.split('-').str[1]
# df1
# df1.insert(2, "month",list2, True)
# df1
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df1['months'] = df1['Release Date'].str.split('-').str[1]
df1
# Out:
#      SlNo Release Date month month month                    MovieName  \
# 0       1    18-Apr-14   Apr   Apr   Apr                     2 States
# 1       2     4-Jan-13   Jan   Jan   Jan                 Table No. 21
# 2       3    18-Jul-14   Jul   Jul   Jul           Amit Sahni Ki List
# 3       4     4-Jan-13   Jan   Jan   Jan             Rajdhani Express
# 4       5     4-Jul-14   Jul   Jul   Jul                 Bobby Jasoos
# ..    ...          ...   ...   ...   ...                          ...
# 144   145    27-Feb-15   Feb   Feb   Feb           Dum Laga Ke Haisha
# 145   146    13-Mar-15   Mar   Mar   Mar                         NH10
# 146   147    20-Mar-15   Mar   Mar   Mar  Dilliwali Zaalim Girlfriend
# 147   148    20-Mar-15   Mar   Mar   Mar                     Hunterrr
# 148   149    23-May-14   May   May   May                Kochadaiiyaan
#
#     ReleaseTime      Genre  Budget  BoxOfficeCollection  YoutubeViews  \
# ...

# %%
df1['months'].mode()
# Out:
# 0    Jan
# Name: months, dtype: object

# %%
highmonth = df1[df1.Budget>=25]
highmonth.months.mode()
# Out:
# 0    Feb
# Name: months, dtype: object

# %%
df['ROI'] = (df['BoxOfficeCollection'].astype(int)-df['Budget'].astype(int))/(df['Budget'].astype(int))
success = df.sort_values(by = "ROI", ascending = False).head(10)
success['MovieName']

# %%
df['ReleaseTime'].unique()
for i in df['ReleaseTime'].unique():
    print("average ROI in ",i,"=",df[df.ReleaseTime==i].ROI.mean())

# %%
df['Year']=pd.DatetimeIndex(df['Release Date']).year
df15=pd.crosstab(df.Year,df.shape[0]).sort_values(by=[df.shape[0]])
df15
df15[df.shape[0]].plot.bar()
